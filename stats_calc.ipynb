# %%
# import required modules
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
CF_model = load_model("C:\\Users\\Kunal\\Downloads\\StatsPredictorModels\\CF_stats_predictor.h5")
AMF_model = load_model("C:\\Users\\Kunal\\Downloads\\StatsPredictorModels\\AMF_stats_predictor.h5")
SS_model = load_model("C:\\Users\\Kunal\\Downloads\\StatsPredictorModels\\SS_stats_predictor.h5")
CMF_model = load_model("C:\\Users\\Kunal\\Downloads\\StatsPredictorModels\\CMF_stats_predictor.h5")
DMF_model = load_model("C:\\Users\\Kunal\\Downloads\\StatsPredictorModels\\DMF_stats_predictor.h5")
WF_model = load_model("C:\\Users\\Kunal\\Downloads\\StatsPredictorModels\\WF_stats_predictor.h5")
WMF_model = load_model("C:\\Users\\Kunal\\Downloads\\StatsPredictorModels\\WMF_stats_predictor.h5")
FB_model = load_model("C:\\Users\\Kunal\\Downloads\\StatsPredictorModels\\FB_stats_predictor.h5")
CB_model = load_model("C:\\Users\\Kunal\\Downloads\\StatsPredictorModels\\CB_stats_predictor.h5")
GK_model = load_model("C:\\Users\\Kunal\\Downloads\\StatsPredictorModels\\GK_stats_predictor.h5")

models = [CF_model, 
AMF_model, 
SS_model, 
CMF_model, 
DMF_model, 
WF_model, 
WMF_model, 
FB_model, 
CB_model, 
GK_model]

# %%
cf_df = (pd.read_csv("C:\\Users\\Kunal\\Downloads\\Positions\\CF(1).csv")).drop(['Unnamed: 0','ID', 	'Position', 	'Player Name', 	'Team Name', 	'Nationality','Weight', 	'Age','Price'], axis =1)
wmf_df = (pd.read_csv("C:\\Users\\Kunal\\Downloads\\Positions\\WMF(1).csv")).drop(['Unnamed: 0','ID', 	'Position', 	'Player Name', 	'Team Name', 	'Nationality','Weight', 	'Age','Price'], axis =1)
cmf_df = (pd.read_csv("C:\\Users\\Kunal\\Downloads\\Positions\\CMF(1).csv")).drop(['Unnamed: 0','ID', 	'Position', 	'Player Name', 	'Team Name', 	'Nationality','Weight', 	'Age','Price'], axis =1)
ss_df = (pd.read_csv("C:\\Users\\Kunal\\Downloads\\Positions\\SS(1).csv")).drop(['Unnamed: 0','ID', 	'Position', 	'Player Name', 	'Team Name', 	'Nationality','Weight', 	'Age','Price'], axis =1)
dmf_df = (pd.read_csv("C:\\Users\\Kunal\\Downloads\\Positions\\DMF(1).csv")).drop(['Unnamed: 0','ID', 	'Position', 	'Player Name', 	'Team Name', 	'Nationality','Weight', 	'Age','Price'], axis =1)
cb_df = (pd.read_csv("C:\\Users\\Kunal\\Downloads\\Positions\\CB(1).csv")).drop(['Unnamed: 0','ID', 	'Position', 	'Player Name', 	'Team Name', 	'Nationality','Weight', 	'Age','Price'], axis =1)
gk_df = (pd.read_csv("C:\\Users\\Kunal\\Downloads\\Positions\\GK(1).csv")).drop(['Unnamed: 0','ID', 	'Position', 	'Player Name', 	'Team Name', 	'Nationality','Weight', 	'Age','Price'], axis =1)
amf_df = (pd.read_csv("C:\\Users\\Kunal\\Downloads\\Positions\\AMF(1).csv")).drop(['Unnamed: 0','ID', 	'Position', 	'Player Name', 	'Team Name', 	'Nationality','Weight', 	'Age','Price'], axis =1)
fb_df = (pd.read_csv("C:\\Users\\Kunal\\Downloads\\Positions\\FB(1).csv")).drop(['Unnamed: 0','ID', 	'Position', 	'Player Name', 	'Team Name', 	'Nationality','Weight', 	'Age','Price'], axis =1)
wf_df = (pd.read_csv("C:\\Users\\Kunal\\Downloads\\Positions\\WF(1).csv")).drop(['Unnamed: 0','ID', 	'Position', 	'Player Name', 	'Team Name', 	'Nationality','Weight', 	'Age','Price'], axis =1)

# %%
Allplayer_df = pd.read_csv("C:\\Users\\Kunal\\Downloads\\AllPlayers.csv")

# %%
Allplayer_df
# Out:
#       Height  Offensive Awareness  Ball Control  Dribbling  Tight Possession  \
# 0        180                   85            78         70                74
# 1        178                   77            68         69                65
# 2        185                   90            86         81                83
# 3        183                   80            78         81                77
# 4        180                   84            77         76                73
# ...      ...                  ...           ...        ...               ...
# 7261     188                   45            53         47                48
# 7262     183                   42            57         45                47
# 7263     187                   41            56         44                49
# 7264     192                   42            60         44                43
# 7265     190                   41            56         46                48
#
# ...

# %%
cf_X = cf_df.drop('Overall Rating', axis =1)
ss_X = ss_df.drop('Overall Rating', axis =1)
amf_X = amf_df.drop('Overall Rating', axis =1)
wf_X = wf_df.drop('Overall Rating', axis =1)
cmf_X = cmf_df.drop('Overall Rating', axis =1)
dmf_X = dmf_df.drop('Overall Rating', axis =1)
wmf_X = wmf_df.drop('Overall Rating', axis =1)
cb_X = cb_df.drop('Overall Rating', axis =1)
fb_X = fb_df.drop('Overall Rating', axis =1)
gk_X = gk_df.drop('Overall Rating', axis =1)

# %%
cf_scaler = MinMaxScaler()
ss_scaler = MinMaxScaler()
amf_scaler = MinMaxScaler()
wf_scaler = MinMaxScaler()
cmf_scaler = MinMaxScaler()
dmf_scaler = MinMaxScaler()
wmf_scaler = MinMaxScaler()
cb_scaler = MinMaxScaler()
fb_scaler = MinMaxScaler()
gk_scaler = MinMaxScaler()

# %%
cf_X = cf_scaler.fit_transform(cf_X)
ss_X = ss_scaler.fit_transform(ss_X)
amf_X = amf_scaler.fit_transform(amf_X)
cmf_X = cmf_scaler.fit_transform(cmf_X)
dmf_X = dmf_scaler.fit_transform(dmf_X)
wf_X = wf_scaler.fit_transform(wf_X)
wmf_X = wmf_scaler.fit_transform(wmf_X)
cb_X = cb_scaler.fit_transform(cb_X)
fb_X = fb_scaler.fit_transform(fb_X)
gk_X = gk_scaler.fit_transform(gk_X)

# %%
cf_df
# Out:
#      Height  Offensive Awareness  Ball Control  Dribbling  Tight Possession  \
# 0       180                   85            78         70                74
# 1       178                   77            68         69                65
# 2       185                   90            86         81                83
# 3       183                   80            78         81                77
# 4       180                   84            77         76                73
# ..      ...                  ...           ...        ...               ...
# 923     182                   79            74         75                71
# 924     184                   81            78         75                75
# 925     183                   73            77         76                79
# 926     178                   72            77         75                73
# 927     196                   85            75         68                72
#
# ...

# %%
x = (input("Enter the stats of the player: "))
pl = list(map(int, x.split(",")))

Allplayer_df = Allplayer_df._append(pd.Series(pl, index=Allplayer_df.columns[:len(pl)]), ignore_index=True)

# %%
player = Allplayer_df.drop('Overall Rating',axis=1).iloc[len(Allplayer_df)-1]

# %%
Allplayer_df
# Out:
#       Height  Offensive Awareness  Ball Control  Dribbling  Tight Possession  \
# 0        180                   85            78         70                74
# 1        178                   77            68         69                65
# 2        185                   90            86         81                83
# 3        183                   80            78         81                77
# 4        180                   84            77         76                73
# ...      ...                  ...           ...        ...               ...
# 7262     183                   42            57         45                47
# 7263     187                   41            56         44                49
# 7264     192                   42            60         44                43
# 7265     190                   41            56         46                48
# 7266     180                   76            91         88                89
#
# ...

# %%
print("Position\n1.CF\n2.SS\n3.WF\n4.WMF\n5.AMF\n6.CMF\n7.DMF\n8.FB\n9.CB\n10.GK")
while True:
    player = Allplayer_df.drop('Overall Rating',axis=1).iloc[len(Allplayer_df)-1]
    x = input("What position you want to know overall rating for type the index(Type n/N to break): ")
    if x == "1":
        player = cf_scaler.transform(player.values.reshape(-1,27))
        print(CF_model.predict(player).round())
    elif x == "2":
        player = ss_scaler.transform(player.values.reshape(-1,27))
        print(SS_model.predict(player).round())
    elif x == "3":
        player = wf_scaler.transform(player.values.reshape(-1,27))
        print(WF_model.predict(player).round())
    elif x == "4":
        player = wmf_scaler.transform(player.values.reshape(-1,27))
        print(WMF_model.predict(player).round())
    elif x == "5":
        player = amf_scaler.transform(player.values.reshape(-1,27))
        print(AMF_model.predict(player).round())
    elif x == "6":
        player = cmf_scaler.transform(player.values.reshape(-1,27))
        print(CMF_model.predict(player).round())
    elif x == "7":
        player = dmf_scaler.transform(player.values.reshape(-1,27))
        print(DMF_model.predict(player).round())
    elif x == "8":
        player = fb_scaler.transform(player.values.reshape(-1,27))
        print(FB_model.predict(player).round())
    elif x == "9":
        player = cb_scaler.transform(player.values.reshape(-1,27))
        print(CB_model.predict(player).round())
    elif x == "10":
        player = gk_scaler.transform(player.values.reshape(-1,27))
        print(GK_model.predict(player).round())
    elif x.lower() == "n":
        break
    player = Allplayer_df.drop('Overall Rating',axis=1).iloc[7266]
# Out:
# Position
# 1.CF
# 2.SS
# 3.WF
# 4.WMF
# 5.AMF
# 6.CMF
# 7.DMF
# 8.FB
# 9.CB
# 10.GK
# 1/1 [==============================] - 0s 77ms/step
# c:\Users\Kunal\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [[100.]]
# 1/1 [==============================] - 0s 64ms/step
# c:\Users\Kunal\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [[100.]]
# 1/1 [==============================] - 0s 32ms/step
# c:\Users\Kunal\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [[100.]]
# 1/1 [==============================] - 0s 69ms/step
# ...
